# %%
import pandas as pd

# %% [markdown]
# # Reading Excel file

# %%
# By default it loads first sheet 
pd.read_excel(r"C:\Users\pujak\Downloads\Time-Cost-Quality of Hire.xlsx")
# Out:
# C:\Users\pujak\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)
#     Sl. No  Fiscal Year  Quarter  Department Job Open Date  Hire Date  \
# 0        1         2018        1  Production    2018-01-04 2018-02-03
# 1        2         2018        1  Production    2018-01-05 2018-02-02
# 2        3         2018        1  Production    2018-02-04 2018-04-05
# 3        4         2018        1          IT    2018-02-04 2018-03-03
# 4        5         2018        1  Production    2018-02-04 2018-03-04
# ..     ...          ...      ...         ...           ...        ...
# 59      60         2018        4       Sales    2018-11-05 2019-02-01
# 60      61         2018        4   Marketing    2018-11-07 2019-01-02
# 61      62         2018        4  Production    2018-11-07 2019-01-05
# 62      63         2018        4  Production    2018-11-11 2018-12-01
# ...

# %% [markdown]
# # Reading a particular Sheet

# %%
# sheet_name parameters
pd.read_excel(r"C:\Users\pujak\Downloads\Time-Cost-Quality of Hire.xlsx", sheet_name = 'Cost of Hire')
# Out:
#   Type of Hire     Source of Hire    Cost                Remarks
# 0     External         Job Boards   42000             Annual Fee
# 1     External           LinkedIn   60000             Annual Fee
# 2     External      Career Portal   70000  Annual Fee for Server
# 3     External             Agency  802080    12 % of offered CTC
# 4     Internal  Employee Referral  180000     10000 per employee

# %% [markdown]
# # Reading Multiple Sheets

# %%
# passing list of sheets in sheet_name parameter
sheet1, sheet2 = pd.read_excel(r"C:\Users\pujak\Downloads\Time-Cost-Quality of Hire.xlsx", sheet_name = ['Cost of Hire', 'ToH Table']).values()
sheet1
# Out:
#   Type of Hire     Source of Hire    Cost                Remarks
# 0     External         Job Boards   42000             Annual Fee
# 1     External           LinkedIn   60000             Annual Fee
# 2     External      Career Portal   70000  Annual Fee for Server
# 3     External             Agency  802080    12 % of offered CTC
# 4     Internal  Employee Referral  180000     10000 per employee

# %%
sheet2
# Out:
#     Dept Code  Job Code  Source of Hire Code  Gender Code  Time to Hire
# 0           1         1                    4            1            30
# 1           1         1                    2            1            28
# 2           1         1                    5            1            60
# 3           4         5                    2            1            27
# 4           1         1                    3            0            28
# ..        ...       ...                  ...          ...           ...
# 59          3         4                    4            0            88
# 60          2         3                    5            1            56
# 61          1         1                    1            1            59
# 62          1         1                    3            1            20
# 63          1         1                    3            0            28
#
# [64 rows x 5 columns]

# %% [markdown]
# # Reading Text File

# %%
df = pd.read_csv(r"C:\Users\pujak\Downloads\schedule.txt", sep = '-', names = ['Date', 'Total Time'], parse_dates = ['Date'])
df
# Out:
#         Date Total Time
# 0 2025-02-10       3:02
# 1 2025-03-10       2:20

# %% [markdown]
# # Working With JSON File

# %%
pd.read_json(r"C:\Users\pujak\Downloads\archive (14)\iris.json")
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
# importing From Url
import requests 

url = 'https://raw.githubusercontent.com/dudeonthehorse/datasets/refs/heads/master/steam.games.json'

response = requests.get(url)
data = response.json()

pd.json_normalize(data['response']['games'])
# Out:
#       appid                                         name  playtime_forever  \
# 0       240                       Counter-Strike: Source              2845
# 1       280                            Half-Life: Source                40
# 2       360                 Half-Life Deathmatch: Source                 0
# 3      1630              Disciples II: Rise of the Elves                 0
# 4      1640               Disciples II: Gallean's Return                 0
# ..      ...                                          ...               ...
# 187  466560                                    Northgard               133
# 188  379720                                         DOOM               278
# 189  319630                             Life is Strange™                27
# 190  292030                     The Witcher 3: Wild Hunt                 0
# 191  489830  The Elder Scrolls V: Skyrim Special Edition                 0
#
#                                  img_icon_url  \
# ...
